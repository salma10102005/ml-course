# %% [markdown]
# <a href="https://colab.research.google.com/github/salma10102005/ml-course/blob/main/ML_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("let's start a new chapter, anew begening and a new project to know. chhers ")
# Out:
# let's start a new chapter, anew begening and a new project to know. chhers

# %%
print("hello from colab")
# Out:
# hello from colab
